# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
qb_data = open('2021_data/2021_qb_stats.csv', encoding="ISO-8859-1")

qb_df = pd.read_csv(qb_data)
qb_df.head(10)
# Out:
#    Rk            Player   Tm  Age  Pos   G  GS      QBrec  Cmp  Att  ...  \
# 0   1        Tom Brady*  TAM   44  NaN  17  17     13-4-0  485  719  ...
# 1   2   Justin Herbert*  LAC   23   QB  17  17   9/8/2000  443  672  ...
# 2   3  Matthew Stafford  LAR   33   QB  17  17  12/5/2000  404  601  ...
# 3   4  Patrick Mahomes*  KAN   26   QB  17  17  12/5/2000  436  658  ...
# 4   5        Derek Carr  LVR   30   QB  17  17  10/7/2000  428  626  ...
# 5   6        Joe Burrow  CIN   25   QB  16  16  10/6/2000  366  520  ...
# 6   7      Dak Prescott  DAL   28   QB  16  16  11/5/2000  410  596  ...
# 7   8        Josh Allen  BUF   25   QB  17  17  11/6/2000  409  646  ...
# 8   9     Kirk Cousins*  MIN   33   QB  16  16   8/8/2000  372  561  ...
# 9  10    Aaron Rodgers*  GNB   38   QB  16  16     13-3-0  366  531  ...
#
#      Y/G   Rate   QBR  Sk  Yds.1  Sk_per  NY/A  ANY/A  4QC  GWD
# 0  312.7  102.1  68.1  22    144     3.0  6.98   7.41  3.0  5.0
# ...

# %%
wr_data = open('2021_data/2021_wr_stats.csv', encoding="ISO-8859-1")

wr_df = pd.read_csv(wr_data)
wr_df.head(10)
# Out:
#    Rk             Player   Tm  Age Pos   G  GS  Tgt  Rec   Ctch%   Yds   Y/R  \
# 0   1      Cooper Kupp*+  LAR   28  WR  17  17  191  145  75.90%  1947  13.4
# 1   2    Davante Adams*+  GNB   29  WR  16  16  169  123  72.80%  1553  12.6
# 2   3       Tyreek Hill*  KAN   27  WR  17  16  159  111  69.80%  1239  11.2
# 3   4  Justin Jefferson*  MIN   22  WR  17  17  167  108  64.70%  1616  15.0
# 4   5     Mark Andrews*+  BAL   26  te  17   9  153  107  69.90%  1361  12.7
# 5   6   Diontae Johnson*  PIT   25  WR  16  14  169  107  63.30%  1161  10.9
# 6   7      Keenan Allen*  LAC   29  WR  16  16  157  106  67.50%  1138  10.7
# 7   8      Jaylen Waddle  MIA   23  WR  16  16  140  104  74.30%  1015   9.8
# 8   9      Stefon Diggs*  BUF   28  WR  17  17  164  103  62.80%  1225  11.9
# 9  10    Hunter Renfrow*  LVR   26  wr  17   9  128  103  80.50%  1038  10.1
#
#    TD  1D  Lng  Y/Tgt  R/G    Y/G  Fmb
# 0  16  89   59   10.2  8.5  114.5    0
# 1  11  84   59    9.2  7.7   97.1    0
# ...

# %%
rb_data = open('2021_data/2021_rb_stats.csv', encoding="ISO-8859-1")

rb_df = pd.read_csv(rb_data)
rb_df.head(10)
# Out:
#    Rk             Player   Tm  Age Pos   G  GS  Att   Yds  TD   1D  Lng  Y/A  \
# 0   1  Jonathan Taylor*+  IND   22  RB  17  17  332  1811  18  107   83  5.5
# 1   2      Najee Harris*  PIT   23  RB  17  17  307  1200   7   62   37  3.9
# 2   3         Joe Mixon*  CIN   25  RB  16  16  292  1205  13   60   32  4.1
# 3   4     Antonio Gibson  WAS   23  RB  16  14  258  1037   7   65   27  4.0
# 4   5       Dalvin Cook*  MIN   26  RB  13  13  249  1159   6   57   66  4.7
# 5   6      Alvin Kamara*  NOR   26  rb  13  10  240   898   4   42   30  3.7
# 6   7    Ezekiel Elliott  DAL   26  RB  17  17  237  1002  10   55   47  4.2
# 7   8        Nick Chubb*  CLE   26  RB  14  14  228  1259   8   61   70  5.5
# 8   9   David Montgomery  CHI   24  RB  13  13  225   849   7   55   41  3.8
# 9  10      Derrick Henry  TEN   27  rb   8   8  219   937  10   49   76  4.3
#
#      Y/G  Fmb
# 0  106.5    4
# 1   70.6    0
# 2   75.3    2
# 3   64.8    6
# 4   89.2    3
# 5   69.1    0
# ...
